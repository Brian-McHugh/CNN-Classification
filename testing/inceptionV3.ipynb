# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf
from PIL import Image

import keras
from keras.preprocessing import image
from keras.applications.inception_v3 import (
    InceptionV3, 
    preprocess_input, 
    decode_predictions
)

# %%
# Load the InceptionV3 model
# https://keras.io/applications/#inceptionv3
model = InceptionV3(include_top=True, weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 5s 0us/step

# %%
# Function to load the image, display it and show our InceptionV3 prediction results
def predict(image_path):
    """Use InceptionV3 to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=5))

# %%
# Default Image Size for InceptionV3
image_size = (299, 299)

# Load the image and resize to default image size
image_path = os.path.join("..", "images", "chair_on_back.jpg")

# Make predictions
predict(image_path)
# Out:
# Predicted: [[('n04099969', 'rocking_chair', 0.48796952), ('n03476684', 'hair_slide', 0.075603895), ('n02791124', 'barber_chair', 0.05390179), ('n04355933', 'sunglass', 0.031644844), ('n03376595', 'folding_chair', 0.014021077)]]

# %%
# Try again with rotated image showing the chair upright

###### Prediction as JPG file
# Load the image and resize to default image size
image_path = os.path.join("..", "images", "brown_chair_upright.jpg")

# Make predictions
predict(image_path)
# Out:
# Predicted: [[('n03201208', 'dining_table', 0.07716666), ('n03376595', 'folding_chair', 0.075775154), ('n04099969', 'rocking_chair', 0.040906742), ('n03903868', 'pedestal', 0.034836795), ('n04515003', 'upright', 0.014202372)]]

# %%
###### Prediction as PNG file
# Load the image and resize to default image size
image_path = os.path.join("..", "images", "brown_chair_upright.png")

# Make predictions
predict(image_path)
# Out:
# Predicted: [[('n03376595', 'folding_chair', 0.09617502), ('n03201208', 'dining_table', 0.09617021), ('n04099969', 'rocking_chair', 0.07925935), ('n03903868', 'pedestal', 0.02212548), ('n04515003', 'upright', 0.012786008)]]

# %%
# Try process again with a chair lying on its side, instead of its back

# Load the image and resize to default image size
image_path = os.path.join("..", "images", "chair_on_left_side.jpg")

# Make predictions
predict(image_path)
# Out:
# Predicted: [[('n03961711', 'plate_rack', 0.48623225), ('n04501370', 'turnstile', 0.22876379), ('n04099969', 'rocking_chair', 0.02616347), ('n03125729', 'cradle', 0.0142231835), ('n02788148', 'bannister', 0.012434178)]]

# %%
# See if results change for the new version of the gray chair
image_path = os.path.join("..", "images", "gray_chair_upright.png")
predict(image_path)
# Out:
# Predicted: [[('n04099969', 'rocking_chair', 0.28791294), ('n03961711', 'plate_rack', 0.266265), ('n03125729', 'cradle', 0.052643757), ('n03201208', 'dining_table', 0.00564375), ('n04344873', 'studio_couch', 0.0046754903)]]
